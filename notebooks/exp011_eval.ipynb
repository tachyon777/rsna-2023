# %% [markdown]
# # exp011_eval
# [Notion](https://www.notion.so/exp011-4a459065840b4614b0381125851ca87e?pvs=4)
#
# Copy from: exp009_eval.ipynb

# %%
import os
import random
import sys
import warnings
warnings.filterwarnings('ignore')
from collections import defaultdict
from typing import Tuple, Any

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm

# リポジトリtopに移動
while os.path.basename(os.getcwd()) != 'rsna-2023':
    os.chdir('../')
    if os.getcwd() == '/':
        raise Exception('Could not find project root directory.')

from src.classification.dataset import TestDatasetBowelExtra as TestDataset
from src.classification.dataset import load_df
from src.image_processing import windowing
from src.classification.model import load_models
from src.classification.trainer import evaluate
from src.metrics import logloss

# %% [markdown]
# # Config

# %%
class CFG:
    exp_name = 'exp_011'
    # model config
    # timm backbone
    backbone = 'efficientnet_b4'
    # n_ch: z軸方向のスライス数
    n_ch = 1 # support only 1
    expand_ch_dim = False
    # n_class: bowel_injury, extravasation
    n_class = 2
    label_smoothing = None #Optional(float)
    # hyper params
    init_lr = 5e-5
    min_lr = 1e-6
    weight_decay = 1e-4
    image_size = (512, 512)
    batch_size = 64
    amp = True
    n_epoch = 20
    iteration_per_epoch = 100
    pretrain = True
    freeze_epochs = 1
    noaug_epochs = 1
    # fold config
    n_fold = 6
    include_evaluation = False
    train_folds = 1
    # path
    image_dir = "data/dataset001"
    model_save_dir = "outputs"
    # other config
    seed = 42
    num_workers = 0
    num_gpus = 2
    progress_bar = True
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# label dict
label_index_dict_inv = {
    0: 'bowel_injury',
    1: 'extravasation'
}
# load dataframe
df_train = pd.read_csv('data/rsna-2023-abdominal-trauma-detection/train.csv')
df_train_image_level = pd.read_csv('data/rsna-2023-abdominal-trauma-detection/image_level_labels.csv')
df_train_series_meta = pd.read_csv('data/rsna-2023-abdominal-trauma-detection/train_series_meta.csv')

# %%
df = load_df(CFG)
df_eval = df[df["fold"] == 0].reset_index(drop=True)
df_eval.head()
# Out:
#    patient_id  series_id  image_id  bowel  extravasation  fold  weight
# 0       10007      47578        25      0              0     0     1.0
# 1       10007      47578        26      0              0     0     1.0
# 2       10007      47578        27      0              0     0     1.0
# 3       10007      47578        28      0              0     0     1.0
# 4       10007      47578        29      0              0     0     1.0

# %%
def apply_preprocess(image: np.ndarray)-> np.ndarray:
    """データ前処理. カスタマイズして使用.
    Args:
        image (numpy.ndarray): HU値のCT画像.
    Returns:
        image (numpy.ndarray): windowing及び0~1に正規化.
    """
    # 0~1に正規化
    image = windowing(image, wl=0, ww=400, mode="float32")
    return image

# %% [markdown]
# # Load models

# %%
# モデルの読み込み
models = load_models(CFG, mode="final", framework='timm')

# %% [markdown]
# # Evaluation

# %%
def evaluate_series(CFG: Any, df: pd.DataFrame, models: list, pid: int, sid: int) -> dict:
    """患者ごと(シリーズごと)の評価を行う.
    Args:
        CFG (Any): Config
        models (list): 学習済みモデルのリスト
        pid (int): 患者ID
        sid (int): シリーズID
    Returns:
        dict: 評価結果
    """
    # 評価用データセットの作成
    df_res = df[(df["patient_id"] == pid) & (df["series_id"] == sid)].reset_index(drop=True)
    ds = TestDataset(CFG, df_res, preprocess=apply_preprocess)
    eval_iterator = DataLoader(
        ds,
        shuffle=False,
        batch_size=CFG.batch_size,
        num_workers=CFG.num_workers
    )
    # 推論
    result = evaluate(CFG, models, eval_iterator)
    return result

# %%
pid, sid = df_eval["patient_id"][0], df_eval["series_id"][0]
result = evaluate_series(CFG, df_eval, models, pid, sid)

# %%
def calc_metric(metrics: list)->None:
    p, y = [], []
    for i in range(len(metrics)):
        p.append(metrics[i][0])
        y.append(metrics[i][1])
    print(f"logloss: {logloss(np.array(p), np.array(y), norm=False):.4f}")

def print_result(pid: int, sid: int, result: dict)-> None:
    """予測結果のmaxをとり、患者レベルでのaccuracyを見る."""
    print(f"pid: {pid}, sid: {sid}")
    label = result["label"]
    pred = result["pred"]
    ret = [[] for _ in range(2)]
    for index, label_name in label_index_dict_inv.items():
        l = label[:, index]
        p = pred[:, index]
        l = max(l)
        p = max(p)
        print(f"{label_name} max: {l}, pred max: {p:.3f}")
        ret[0].append(p)
        ret[1].append(l)
    return ret

# %%
df_eval_unique = df_eval.drop_duplicates(subset=["patient_id", "series_id"]).reset_index(drop=True)
metrics = []
for i in range(100): #3: oraganごとにrowがあるため
    pid, sid = df_eval_unique["patient_id"][i], df_eval_unique["series_id"][i]
    result = evaluate_series(CFG, df_eval, models, pid, sid)
    metrics.append(print_result(pid, sid, result))
calc_metric(metrics)
# Out:
# pid: 10007, sid: 47578
# bowel_injury max: 0.0, pred max: 0.186
# extrabasation max: 0.0, pred max: 0.181
# pid: 10205, sid: 65236
# bowel_injury max: 0.0, pred max: 0.904
# extrabasation max: 0.0, pred max: 0.302
# pid: 10275, sid: 14254
# bowel_injury max: 0.0, pred max: 0.010
# extrabasation max: 0.0, pred max: 0.104
# pid: 10275, sid: 37142
# bowel_injury max: 0.0, pred max: 0.018
# extrabasation max: 0.0, pred max: 0.086
# pid: 10430, sid: 47009
# bowel_injury max: 0.0, pred max: 0.007
# extrabasation max: 0.0, pred max: 0.235
# pid: 10430, sid: 52259
# bowel_injury max: 0.0, pred max: 0.017
# extrabasation max: 0.0, pred max: 0.104
# pid: 10494, sid: 65369
# bowel_injury max: 0.0, pred max: 0.424
# extrabasation max: 1.0, pred max: 0.360
# pid: 10696, sid: 62306
# bowel_injury max: 0.0, pred max: 0.018
# extrabasation max: 0.0, pred max: 0.052
# pid: 10987, sid: 5611
# bowel_injury max: 0.0, pred max: 0.224
# extrabasation max: 0.0, pred max: 0.184
# pid: 11130, sid: 8511
# bowel_injury max: 0.0, pred max: 0.040
# extrabasation max: 0.0, pred max: 0.354
# pid: 11139, sid: 24201
# bowel_injury max: 0.0, pred max: 0.056
# extrabasation max: 0.0, pred max: 0.073
# pid: 11139, sid: 31481
# bowel_injury max: 0.0, pred max: 0.187
# extrabasation max: 0.0, pred max: 0.029
# pid: 11378, sid: 16846
# bowel_injury max: 0.0, pred max: 0.126
# extrabasation max: 0.0, pred max: 0.079
# pid: 11378, sid: 53429
# bowel_injury max: 0.0, pred max: 0.664
# extrabasation max: 0.0, pred max: 0.131
# pid: 11433, sid: 16534
# bowel_injury max: 0.0, pred max: 0.755
# extrabasation max: 0.0, pred max: 0.345
# pid: 11433, sid: 64815
# bowel_injury max: 0.0, pred max: 0.240
# extrabasation max: 0.0, pred max: 0.546
# pid: 11547, sid: 6116
# bowel_injury max: 0.0, pred max: 0.031
# extrabasation max: 0.0, pred max: 0.140
# pid: 11656, sid: 37803
# bowel_injury max: 0.0, pred max: 0.451
# extrabasation max: 0.0, pred max: 0.132
# pid: 11793, sid: 55528
# bowel_injury max: 0.0, pred max: 0.356
# extrabasation max: 0.0, pred max: 0.279
# pid: 11908, sid: 10773
# bowel_injury max: 0.0, pred max: 0.309
# extrabasation max: 0.0, pred max: 0.095
# pid: 1192, sid: 39389
# bowel_injury max: 0.0, pred max: 0.682
# extrabasation max: 0.0, pred max: 0.136
# pid: 11925, sid: 33599
# bowel_injury max: 1.0, pred max: 0.898
# extrabasation max: 0.0, pred max: 0.275
# pid: 11925, sid: 60003
# bowel_injury max: 1.0, pred max: 0.818
# extrabasation max: 1.0, pred max: 0.395
# pid: 12086, sid: 16498
# bowel_injury max: 0.0, pred max: 0.263
# extrabasation max: 0.0, pred max: 0.187
# pid: 12086, sid: 47491
# bowel_injury max: 0.0, pred max: 0.292
# extrabasation max: 0.0, pred max: 0.131
# pid: 12332, sid: 15276
# bowel_injury max: 1.0, pred max: 0.197
# extrabasation max: 0.0, pred max: 0.067
# pid: 12332, sid: 2793
# bowel_injury max: 1.0, pred max: 0.360
# extrabasation max: 0.0, pred max: 0.044
# pid: 12450, sid: 13297
# bowel_injury max: 0.0, pred max: 0.049
# extrabasation max: 0.0, pred max: 0.084
# pid: 12485, sid: 34212
# bowel_injury max: 0.0, pred max: 0.408
# extrabasation max: 0.0, pred max: 0.132
# pid: 12485, sid: 8754
# bowel_injury max: 0.0, pred max: 0.797
# extrabasation max: 0.0, pred max: 0.602
# pid: 1250, sid: 56073
# bowel_injury max: 0.0, pred max: 0.138
# extrabasation max: 0.0, pred max: 0.186
# pid: 12510, sid: 18649
# bowel_injury max: 0.0, pred max: 0.835
# extrabasation max: 0.0, pred max: 0.161
# pid: 12510, sid: 33610
# bowel_injury max: 0.0, pred max: 0.797
# extrabasation max: 0.0, pred max: 0.160
# pid: 12667, sid: 16083
# bowel_injury max: 0.0, pred max: 0.084
# extrabasation max: 0.0, pred max: 0.090
# pid: 12744, sid: 37732
# bowel_injury max: 0.0, pred max: 0.439
# extrabasation max: 0.0, pred max: 0.241
# pid: 12744, sid: 47219
# bowel_injury max: 0.0, pred max: 0.053
# extrabasation max: 0.0, pred max: 0.139
# pid: 12967, sid: 55621
# bowel_injury max: 0.0, pred max: 0.657
# extrabasation max: 0.0, pred max: 0.621
# pid: 13012, sid: 38013
# bowel_injury max: 0.0, pred max: 0.119
# extrabasation max: 0.0, pred max: 0.058
# pid: 13106, sid: 12049
# bowel_injury max: 0.0, pred max: 0.068
# extrabasation max: 0.0, pred max: 0.133
# pid: 13106, sid: 5011
# bowel_injury max: 0.0, pred max: 0.028
# extrabasation max: 0.0, pred max: 0.155
# pid: 13231, sid: 31094
# bowel_injury max: 0.0, pred max: 0.102
# extrabasation max: 0.0, pred max: 0.052
# pid: 13231, sid: 769
# bowel_injury max: 0.0, pred max: 0.039
# extrabasation max: 0.0, pred max: 0.068
# pid: 13310, sid: 45088
# bowel_injury max: 0.0, pred max: 0.175
# extrabasation max: 0.0, pred max: 0.128
# pid: 13571, sid: 54285
# bowel_injury max: 0.0, pred max: 0.335
# extrabasation max: 0.0, pred max: 0.088
# pid: 13604, sid: 24652
# bowel_injury max: 0.0, pred max: 0.555
# extrabasation max: 0.0, pred max: 0.051
# pid: 13604, sid: 42939
# bowel_injury max: 0.0, pred max: 0.431
# extrabasation max: 0.0, pred max: 0.124
# pid: 14052, sid: 29512
# bowel_injury max: 0.0, pred max: 0.330
# extrabasation max: 0.0, pred max: 0.275
# pid: 14052, sid: 7806
# bowel_injury max: 0.0, pred max: 0.166
# extrabasation max: 0.0, pred max: 0.051
# pid: 14091, sid: 48197
# bowel_injury max: 0.0, pred max: 0.067
# extrabasation max: 0.0, pred max: 0.175
# pid: 14102, sid: 24136
# bowel_injury max: 0.0, pred max: 0.036
# extrabasation max: 1.0, pred max: 0.299
# pid: 14178, sid: 62202
# bowel_injury max: 0.0, pred max: 0.022
# extrabasation max: 0.0, pred max: 0.242
# pid: 14309, sid: 12900
# bowel_injury max: 0.0, pred max: 0.395
# extrabasation max: 0.0, pred max: 0.073
# pid: 14309, sid: 53843
# bowel_injury max: 0.0, pred max: 0.411
# extrabasation max: 0.0, pred max: 0.130
# pid: 14351, sid: 24224
# bowel_injury max: 0.0, pred max: 0.001
# extrabasation max: 0.0, pred max: 0.056
# pid: 14351, sid: 43472
# bowel_injury max: 0.0, pred max: 0.001
# extrabasation max: 0.0, pred max: 0.113
# pid: 14388, sid: 12312
# bowel_injury max: 0.0, pred max: 0.067
# extrabasation max: 0.0, pred max: 0.042
# pid: 14388, sid: 6738
# bowel_injury max: 0.0, pred max: 0.049
# extrabasation max: 0.0, pred max: 0.109
# pid: 14393, sid: 47591
# bowel_injury max: 0.0, pred max: 0.062
# extrabasation max: 0.0, pred max: 0.104
# pid: 14517, sid: 1621
# bowel_injury max: 0.0, pred max: 0.085
# extrabasation max: 0.0, pred max: 0.211
# pid: 14590, sid: 45895
# bowel_injury max: 0.0, pred max: 0.081
# extrabasation max: 0.0, pred max: 0.393
# pid: 14590, sid: 63177
# bowel_injury max: 0.0, pred max: 0.453
# extrabasation max: 0.0, pred max: 0.260
# pid: 14788, sid: 18931
# bowel_injury max: 0.0, pred max: 0.152
# extrabasation max: 1.0, pred max: 0.112
# pid: 14788, sid: 29104
# bowel_injury max: 0.0, pred max: 0.069
# extrabasation max: 0.0, pred max: 0.224
# pid: 14831, sid: 40855
# bowel_injury max: 0.0, pred max: 0.792
# extrabasation max: 0.0, pred max: 0.080
# pid: 14831, sid: 58727
# bowel_injury max: 0.0, pred max: 0.612
# extrabasation max: 0.0, pred max: 0.085
# pid: 14846, sid: 42425
# bowel_injury max: 0.0, pred max: 0.397
# extrabasation max: 0.0, pred max: 0.187
# pid: 14963, sid: 4059
# bowel_injury max: 0.0, pred max: 0.194
# extrabasation max: 0.0, pred max: 0.094
# pid: 14989, sid: 41296
# bowel_injury max: 0.0, pred max: 0.565
# extrabasation max: 0.0, pred max: 0.131
# pid: 14989, sid: 59710
# bowel_injury max: 0.0, pred max: 0.198
# extrabasation max: 0.0, pred max: 0.067
# pid: 15035, sid: 34385
# bowel_injury max: 0.0, pred max: 0.303
# extrabasation max: 0.0, pred max: 0.044
# pid: 15035, sid: 44442
# bowel_injury max: 0.0, pred max: 0.711
# extrabasation max: 0.0, pred max: 0.188
# pid: 15057, sid: 56629
# bowel_injury max: 0.0, pred max: 0.016
# extrabasation max: 0.0, pred max: 0.043
# pid: 1526, sid: 40307
# bowel_injury max: 0.0, pred max: 0.073
# extrabasation max: 0.0, pred max: 0.105
# pid: 15362, sid: 36509
# bowel_injury max: 0.0, pred max: 0.372
# extrabasation max: 0.0, pred max: 0.492
# pid: 15492, sid: 44581
# bowel_injury max: 0.0, pred max: 0.460
# extrabasation max: 0.0, pred max: 0.238
# pid: 15611, sid: 11556
# bowel_injury max: 0.0, pred max: 0.306
# extrabasation max: 0.0, pred max: 0.052
# pid: 15773, sid: 32127
# bowel_injury max: 0.0, pred max: 0.470
# extrabasation max: 0.0, pred max: 0.015
# pid: 15773, sid: 57350
# bowel_injury max: 0.0, pred max: 0.619
# extrabasation max: 0.0, pred max: 0.010
# pid: 15876, sid: 38633
# bowel_injury max: 1.0, pred max: 0.062
# extrabasation max: 0.0, pred max: 0.069
# pid: 15956, sid: 13043
# bowel_injury max: 0.0, pred max: 0.017
# extrabasation max: 0.0, pred max: 0.017
# pid: 15956, sid: 28209
# bowel_injury max: 0.0, pred max: 0.029
# extrabasation max: 0.0, pred max: 0.073
# pid: 16000, sid: 39325
# bowel_injury max: 0.0, pred max: 0.237
# extrabasation max: 0.0, pred max: 0.056
# pid: 16000, sid: 39717
# bowel_injury max: 0.0, pred max: 0.178
# extrabasation max: 0.0, pred max: 0.200
# pid: 16120, sid: 9598
# bowel_injury max: 0.0, pred max: 0.535
# extrabasation max: 0.0, pred max: 0.496
# pid: 16229, sid: 52932
# bowel_injury max: 0.0, pred max: 0.459
# extrabasation max: 0.0, pred max: 0.153
# pid: 16229, sid: 6304
# bowel_injury max: 0.0, pred max: 0.601
# extrabasation max: 0.0, pred max: 0.158
# pid: 16240, sid: 22002
# bowel_injury max: 0.0, pred max: 0.104
# extrabasation max: 0.0, pred max: 0.182
# pid: 16368, sid: 15406
# bowel_injury max: 0.0, pred max: 0.077
# extrabasation max: 0.0, pred max: 0.113
# pid: 16477, sid: 14489
# bowel_injury max: 0.0, pred max: 0.066
# extrabasation max: 0.0, pred max: 0.100
# pid: 16477, sid: 36052
# bowel_injury max: 0.0, pred max: 0.290
# extrabasation max: 0.0, pred max: 0.521
# pid: 16722, sid: 48930
# bowel_injury max: 0.0, pred max: 0.311
# extrabasation max: 0.0, pred max: 0.137
# pid: 16836, sid: 15920
# bowel_injury max: 0.0, pred max: 0.654
# extrabasation max: 0.0, pred max: 0.499
# pid: 16935, sid: 59318
# bowel_injury max: 0.0, pred max: 0.976
# extrabasation max: 0.0, pred max: 0.106
# pid: 16963, sid: 13131
# bowel_injury max: 0.0, pred max: 0.024
# extrabasation max: 0.0, pred max: 0.233
# pid: 16963, sid: 6910
# bowel_injury max: 0.0, pred max: 0.338
# extrabasation max: 0.0, pred max: 0.483
# pid: 17264, sid: 30494
# bowel_injury max: 0.0, pred max: 0.327
# extrabasation max: 0.0, pred max: 0.190
# pid: 17264, sid: 8766
# bowel_injury max: 0.0, pred max: 0.636
# extrabasation max: 0.0, pred max: 0.136
# pid: 17265, sid: 52279
# bowel_injury max: 0.0, pred max: 0.235
# extrabasation max: 1.0, pred max: 0.489
# pid: 17350, sid: 13731
# bowel_injury max: 0.0, pred max: 0.004
# extrabasation max: 0.0, pred max: 0.022
# pid: 17350, sid: 37587
# bowel_injury max: 0.0, pred max: 0.005
# extrabasation max: 0.0, pred max: 0.028
# logloss: 0.0508
